# %%
# load the "fmri" dataset using the load_dataset function of seaborn. plot a line plot.

# %%
import seaborn as sns

# %%
data = sns.load_dataset('fmri')

# %%
data
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x = data.timepoint , y = data.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
# use the "diamonds" dataset using load_dataset function of seaborn to plot histogram for the price column. use hue parameter for the cut column.

# %%
diamond = sns.load_dataset('diamonds')

# %%
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.displot(diamond['price'])

# %%
sns.displot(x = diamond.price, y = diamond.cut, data = diamond , hue =  'cut')

# %%
# use the iris dataset from seaborn to plot a pair plot. use hue parameter for species column.

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x = iris.sepal_length, y = iris.sepal_width , data = iris, hue = 'species')
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x = iris.petal_width, y = iris.petal_length)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.scatterplot(x = iris.petal_length, y = iris.sepal_width)
# Out:
# <AxesSubplot: xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.displot(iris['sepal_length'])

# %%
sns.relplot(x =iris.petal_length , y = iris.petal_width , data = iris , style = 'species',  hue ='sepal_length')

# %%
sns.relplot(x =iris.petal_length , y = iris.petal_width , data = iris , hue = 'species')

# %%
sns.relplot(x =iris.sepal_width , y = iris.sepal_length , data = iris , hue = 'species')

# %%
sns.jointplot(iris)

# %%
sns.pairplot(iris) # pair plot command shows error as i check the above codes there is no issue in it .
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In [18], line 1
# ----> 1 sns.pairplot(iris)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:2144, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2142 diag_kws.setdefault("legend", False)
#    2143 if diag_kind == "hist":
# -> 2144     grid.map_diag(histplot, **diag_kws)
#    2145 elif diag_kind == "kde":
#    2146     diag_kws.setdefault("fill", True)
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1506     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1507     func(x=vector, **plot_kwargs)
#    1508     ax.legend_ = None
# ...

# %%
# use the flights dataset from seaborn to plot a heatmap.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
flights = sns.load_dataset('flights')

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = flights.pivot("month", "year", "passengers")
ax = sns.heatmap(flights)
plt.title("Heatmap Flight Data")
plt.show()
# Out:
# /tmp/ipykernel_1558/1137614777.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("month", "year", "passengers")

# %%
# load the titanic dataset using the load_dataset function of seaborn. plot two box plots x = pclass, y = age and y = fare .

# %%
titanic = sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# boxplot 1
sns.boxplot(x='pclass',y='age',data=titanic,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
# boxplot 2
sns.boxplot(x='class',y='fare',data=titanic,palette='rainbow')
# Out:
# <AxesSubplot: xlabel='class', ylabel='fare'>

# %%
# name the five plots that we can plot using seaborn library. also state the use of each plot .

# %%
1.Line Plot
A Line Plot Is The Simplest Plot In All Plotting Types, As It Is The Visualization Of A Single Function.
This Plot Helps Us To See The Relationship Between X-Axis, Y-Axis And It Also Takes Some Parameters Such As Hue, Size, Color, Etc.

# %%
2.Bar Plot
A Bar Chart Is A Way Of Comparing A Set Of Categorical Data.
It Is Better To Convert Continuous Data To Bins Before Plotting.
The Bar Chart Displays Data Using Several Bars, Each Representing A Particular Category.

# %%
3.Pair Plot
Pair Plot Creates A Grid Of Axis Such That Each Numeric Variable In Data Will Create A Plot Between Each Other
The Y-Axis Across A Single Row And The X-Axis Across A Single Column.
The Diagonal Plots Are A Univariate Distribution Plot That Helps To Draw The Marginal Distribution Of The Data In Each Column.

# %%
4.Scatter Plot
Scatter Plot Is The Same As A Line Plot, In A Line Plot Instead Of Points Being Joined By Line Segments,
The Points Are Shown Individually With A Dot, Circle, Or Any Other Shape

# %%
5.Histogram 
A Histogram Is A Graph That Shows The Underlying Frequency Distribution Of A Set Of Continuous Data. 
This Chart Is Helpful In Data Collection And Data Analysis And Hence It Is Widely Used In The Analytics Industry.
By Plotting It Allows To Inspect The Overall Distribution Of The Data, Outlier, Skew Present In The Data.
